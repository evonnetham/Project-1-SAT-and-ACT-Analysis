# %% [markdown]
# # Project 1: SAT & ACT Analysis
#
# ### Part 2 Exploratory Data Analysis
#
# _By: Evonne Tham_

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Import

# %%
# Read in Final Dataset
final = pd.read_csv("../dataset/final.csv")
final.head()
# Out:
#         state  sat_part_17  sat_erw_17  sat_math_17  sat_total_17  \
# 0     Alabama         0.05         593          572          1165
# 1      Alaska         0.38         547          533          1080
# 2     Arizona         0.30         563          553          1116
# 3    Arkansas         0.03         614          594          1208
# 4  California         0.53         531          524          1055
#
#    act_part_17  act_eng_17  act_math_17  act_read_17  act_sci_17  ...  \
# 0         1.00        18.9         18.4         19.7        19.4  ...
# 1         0.65        18.7         19.8         20.4        19.9  ...
# 2         0.62        18.6         19.8         20.1        19.8  ...
# 3         1.00        18.9         19.0         19.7        19.5  ...
# 4         0.31        22.5         22.7         23.1        22.2  ...
#
#    sat_part_18  sat_erw_18  sat_math_18  sat_total_18  act_part_18  \
# 0         0.06         595          571          1166         1.00
# 1         0.43         562          544          1106         0.33
# 2         0.29         577          572          1149         0.66
# 3         0.05         592          576          1169         1.00
# 4         0.60         540          536          1076         0.27
#
#    act_eng_18  act_math_18  act_read_18  act_sci_18  act_composite_18
# 0        18.9         18.3         19.6        19.0              19.1
# 1        19.8         20.6         21.6        20.7              20.8
# 2        18.2         19.4         19.5        19.2              19.2
# 3        19.1         18.9         19.7        19.4              19.4
# 4        22.5         22.5         23.0        22.1              22.7
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.describe().T
# Out:
#                   count       mean        std     min        25%      50%  \
# sat_part_17        50.0     0.3922   0.353849    0.02     0.0400     0.34
# sat_erw_17         50.0   569.7800  45.882410  482.00   532.7500   559.50
# sat_math_17        50.0   557.5400  47.362781  468.00   523.2500   549.50
# sat_total_17       50.0  1127.4200  92.945911  950.00  1055.2500  1107.50
# act_part_17        50.0     0.6600   0.320191    0.08     0.3125     0.71
# act_eng_17         50.0    20.8840   2.352884   16.30    19.0000    20.55
# act_math_17        50.0    21.1440   1.982902   18.00    19.4000    20.90
# act_read_17        50.0    21.9700   2.064298   18.10    20.4250    21.70
# act_sci_17         50.0    21.4160   1.738796   18.20    19.9250    21.30
# act_composite_17   50.0    21.4780   2.019021   17.80    19.8000    21.40
# sat_part_18        50.0     0.4514   0.374395    0.02     0.0425     0.50
# sat_erw_18         50.0   564.0600  47.909102  480.00   534.2500   552.00
# sat_math_18        50.0   556.6600  48.160281  480.00   522.2500   545.50
# sat_total_18       50.0  1120.8200  94.935572  977.00  1055.2500  1098.50
# act_part_18        50.0     0.6226   0.341418    0.07     0.2775     0.66
# act_eng_18         50.0    20.9660   2.465982   16.60    19.1000    20.05
# act_math_18        50.0    21.1080   2.052558   17.80    19.4000    20.65
# act_read_18        50.0    21.9940   2.183651   18.00    20.4250    21.45
# act_sci_18         50.0    21.3280   1.885069   17.90    19.7750    20.95
# act_composite_18   50.0    21.4660   2.122629   17.70    19.9250    21.05
#
#                         75%     max
# sat_part_17          0.6500     1.0
# sat_erw_17         613.5000   644.0
# sat_math_17        601.0000   651.0
# sat_total_17      1214.0000  1295.0
# act_part_17          1.0000     1.0
# act_eng_17          23.1000    25.5
# act_math_17         23.0000    25.3
# act_read_17         23.8750    26.0
# act_sci_17          22.9750    24.9
# act_composite_17    23.4000    25.5
# sat_part_18          0.7675     1.0
# sat_erw_18         612.7500   643.0
# sat_math_18        594.2500   655.0
# sat_total_18      1207.0000  1298.0
# act_part_18          1.0000     1.0
# act_eng_18          23.7000    26.0
# act_math_18         23.1750    25.2
# act_read_18         24.1500    26.1
# act_sci_18          23.0750    24.9
# act_composite_18    23.5750    25.6

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def stddev(x):
    mean = x.mean()
    v = (x-mean)
    v = (v**2).mean()
    return v**0.5

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
sd = {col_title: stddev(final[col_title]) for col_title in final.columns if col_title != 'state'}
sd
# Out:
# {'sat_part_17': 0.3502929631037426,
#  'sat_erw_17': 45.4212681461009,
#  'sat_math_17': 46.88676145779318,
#  'sat_total_17': 92.01175794429753,
#  'act_part_17': 0.3169731849857334,
#  'act_eng_17': 2.3292367848718163,
#  'act_math_17': 1.9629732550394061,
#  'act_read_17': 2.0435508312738393,
#  'act_sci_17': 1.7213204233959463,
#  'act_composite_17': 1.9987285958828933,
#  'sat_part_18': 0.37063194681516604,
#  'sat_erw_18': 47.4275911258415,
#  'sat_math_18': 47.6762456575599,
#  'sat_total_18': 93.98142156830785,
#  'act_part_18': 0.33798704117169925,
#  'act_eng_18': 2.441197247253896,
#  'act_math_18': 2.0319291326224937,
#  'act_read_18': 2.1617039575297996,
#  'act_sci_18': 1.8661232542359036,
#  'act_composite_18': 2.1012957906967786}

# %%
# Cross check between both pandas and manual calculation using np.std
np.std(final)
# Out:
# sat_part_17          0.350293
# sat_erw_17          45.421268
# sat_math_17         46.886761
# sat_total_17        92.011758
# act_part_17          0.316973
# act_eng_17           2.329237
# act_math_17          1.962973
# act_read_17          2.043551
# act_sci_17           1.721320
# act_composite_17     1.998729
# sat_part_18          0.370632
# sat_erw_18          47.427591
# sat_math_18         47.676246
# sat_total_18        93.981422
# act_part_18          0.337987
# act_eng_18           2.441197
# act_math_18          2.031929
# act_read_18          2.161704
# act_sci_18           1.866123
# act_composite_18     2.101296
# dtype: float64

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's
# `std` method?

# %% [markdown]
# ##### Answer:
# The manually calculated and numpy standard deviation and does not match up with the standard deviation in pandas describe because pandas standard deviation function utilises the formula for sample standard deviation where summation values are divided by N-1 instead of N in the manually calculated standard deviation. Furthermore, numpy standard deviation function has “Delta Degrees of Freedom” parameter, which by default is zero. The reason we use a N-1 calculation for sample size is because we want to get an unbiased estimator.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### i. Highest SAT Participation Rate

# %%
# 2017
final[['state', 'sat_part_17']].sort_values(by = ['sat_part_17'], ascending = False).head()
# Out:
#                    state  sat_part_17
# 21              Michigan         1.00
# 6            Connecticut         1.00
# 7               Delaware         1.00
# 8   District of Columbia         1.00
# 28         New Hampshire         0.96

# %%
# 2018 
final[['state', 'sat_part_18']].sort_values(by = ['sat_part_18'], ascending = False).head()
# Out:
#           state  sat_part_18
# 5      Colorado          1.0
# 6   Connecticut          1.0
# 7      Delaware          1.0
# 21     Michigan          1.0
# 12        Idaho          1.0

# %% [markdown]
# ##### Answer:
#
# Michigan, Connecticut, Delaware and District of Columbia have the highest 2017 SAT participation rates at 100%. These states have compulsory testing for SAT.
# As of 2018, Connecticut, Delaware and Michigan continued to have the highest 2018 SAT participation rates at 100%. With new addition of Colorado and Idaho as they made SAT compulsory.
# District of Columbia however dropped from the top list as they made SAT optional.

# %% [markdown]
# ### ii. Lowest SAT Participation Rate

# %%
# 2017
final[['state', 'sat_part_17']].sort_values(by = ['sat_part_17'], ascending = False).tail()
# Out:
#            state  sat_part_17
# 48     Wisconsin         0.03
# 49       Wyoming         0.03
# 33  North Dakota         0.02
# 23   Mississippi         0.02
# 15          Iowa         0.02

# %%
# 2018
final[['state', 'sat_part_18']].sort_values(by = ['sat_part_18'], ascending = False).tail()
# Out:
#            state  sat_part_18
# 40  South Dakota         0.03
# 15          Iowa         0.03
# 48     Wisconsin         0.03
# 49       Wyoming         0.03
# 33  North Dakota         0.02

# %% [markdown]
# ##### Answer:
#
# North Dakota, Mississippi and Lowa has the lowest SAT participation rate of only 2% in 2017. North Dakota remained the lowest in 2018. Apart from that we can see that generally states that have low participation rate display similar rates year on year.

# %% [markdown]
# ### iii. Highest ACT Participation Rate

# %%
# 2017
final[['state', 'act_part_17']].sort_values(by = ['act_part_17'], ascending = False).head(20)
# Out:
#              state  act_part_17
# 0          Alabama         1.00
# 17        Kentucky         1.00
# 48       Wisconsin         1.00
# 43            Utah         1.00
# 41       Tennessee         1.00
# 39  South Carolina         1.00
# 35        Oklahoma         1.00
# 32  North Carolina         1.00
# 27          Nevada         1.00
# 24        Missouri         1.00
# 23     Mississippi         1.00
# 22       Minnesota         1.00
# 18       Louisiana         1.00
# 25         Montana         1.00
# 49         Wyoming         1.00
# 3         Arkansas         1.00
# 5         Colorado         1.00
# 33    North Dakota         0.98
# 13        Illinois         0.93
# 11          Hawaii         0.90

# %%
# 2018
final[['state', 'act_part_18']].sort_values(by = ['act_part_18'], ascending = False).head(20)
# Out:
#              state  act_part_18
# 0          Alabama         1.00
# 17        Kentucky         1.00
# 48       Wisconsin         1.00
# 43            Utah         1.00
# 41       Tennessee         1.00
# 39  South Carolina         1.00
# 35        Oklahoma         1.00
# 34            Ohio         1.00
# 32  North Carolina         1.00
# 27          Nevada         1.00
# 26        Nebraska         1.00
# 24        Missouri         1.00
# 23     Mississippi         1.00
# 18       Louisiana         1.00
# 25         Montana         1.00
# 49         Wyoming         1.00
# 3         Arkansas         1.00
# 22       Minnesota         0.99
# 33    North Dakota         0.98
# 11          Hawaii         0.89

# %% [markdown]
# ##### Answer:
#
# Alabama, Kentucky, Wisconsin, Utah, Tennessee, South Carolina, Oklahoma, North Carolina, Nevada, Missouri, Mississippi, Minnesota, Louisiana, Montana, Wyoming, Arkansas and Colorado have the highest 2017 ACT participation rates at 100%. These states have compulsory ACT.
#
# In 2018 Ohio and Nebraska also made ACT compulsory while Minnesota and Colorado made optional.

# %% [markdown]
# ### iv. Lowest ACT Participation Rate

# %%
# 2017
final[['state', 'act_part_17']].sort_values(by = ['act_part_17'], ascending = False).tail()
# Out:
#             state  act_part_17
# 37   Pennsylvania         0.23
# 38   Rhode Island         0.21
# 28  New Hampshire         0.18
# 7        Delaware         0.18
# 19          Maine         0.08

# %%
# 2018
final[['state', 'act_part_18']].sort_values(by = ['act_part_18'], ascending = False).tail()
# Out:
#             state  act_part_18
# 37   Pennsylvania         0.20
# 7        Delaware         0.17
# 28  New Hampshire         0.16
# 38   Rhode Island         0.15
# 19          Maine         0.07

# %% [markdown]
# Maine remained the lowest participation rate in ACT in 2017 and 2018 with a drop of 1% from 8%

# %% [markdown]
# ### v. Highest SAT Total Score

# %%
# 2017
final[['state', 'sat_total_17']].sort_values(by = ['sat_total_17'], ascending = False).head()
# Out:
#         state  sat_total_17
# 22  Minnesota          1295
# 48  Wisconsin          1291
# 15       Iowa          1275
# 24   Missouri          1271
# 16     Kansas          1260

# %%
# 2018
final[['state', 'sat_total_18']].sort_values(by = ['sat_total_18'], ascending = False).head()
# Out:
#            state  sat_total_18
# 22     Minnesota          1298
# 48     Wisconsin          1294
# 33  North Dakota          1283
# 15          Iowa          1265
# 16        Kansas          1265

# %% [markdown]
# ##### Answer:
#
# Minnesota as the highest total score in both 2017 and 2018 of 1295 and 1298 respectively, which did not vary much from year to year.

# %% [markdown]
# ### vi. Lowest SAT Total Score

# %%
# 2017
final[['state','sat_total_17']].sort_values(by = ['sat_total_17'], ascending = False).tail()
# Out:
#                    state  sat_total_17
# 19                 Maine          1012
# 12                 Idaho          1005
# 21              Michigan          1005
# 7               Delaware           996
# 8   District of Columbia           950

# %%
# 2018
final[['state','sat_total_18']].sort_values(by = ['sat_total_18'], ascending = False).tail()
# Out:
#                    state  sat_total_18
# 11                Hawaii          1010
# 12                 Idaho          1001
# 47         West Virginia           999
# 7               Delaware           998
# 8   District of Columbia           977

# %% [markdown]
# District of Columbia remained the lowest in SAT total score from 2017 to 2018 of 950 to 977.

# %% [markdown]
# ### vii. Highest ACT Composite Score

# %%
# 2017
final[['state','act_composite_17']].sort_values(by = ['act_composite_17'], ascending = False).head()
# Out:
#             state  act_composite_17
# 28  New Hampshire              25.5
# 20  Massachusetts              25.4
# 6     Connecticut              25.2
# 19          Maine              24.3
# 31       New York              24.2

# %% [markdown]
# ##### Answer:
#
# New Hampshire had the highest mean composite score for 2017 ACT

# %%
# 2018
final[['state','act_composite_18']].sort_values(by = ['act_composite_18'], ascending = False).head()
# Out:
#             state  act_composite_18
# 6     Connecticut              25.6
# 20  Massachusetts              25.5
# 28  New Hampshire              25.1
# 31       New York              24.5
# 21       Michigan              24.4

# %% [markdown]
# ##### Answer:
#
# In 2018 Conneticut surpasses New Hampshire and became the highest mean composite score for ACT.

# %% [markdown]
# ### viii. Lowest ACT Composite Score

# %%
# 2017
final[['state','act_composite_17']].sort_values(by = ['act_composite_17'], ascending = False).tail()
# Out:
#              state  act_composite_17
# 32  North Carolina              19.1
# 11          Hawaii              19.0
# 39  South Carolina              18.7
# 23     Mississippi              18.6
# 27          Nevada              17.8

# %%
# 2018
final[['state','act_composite_18']].sort_values(by = ['act_composite_18'], ascending = False).tail()
# Out:
#              state  act_composite_18
# 0          Alabama              19.1
# 11          Hawaii              18.9
# 23     Mississippi              18.6
# 39  South Carolina              18.3
# 27          Nevada              17.7

# %% [markdown]
# ##### Answer:
#
# Nevada had the lowest mean composite score for 2017 ACT and remained the same in 2018

# %% [markdown]
# ### Do any states with 100% participation on a given test have a rate change year-to-year?

# %%
#SAT
final[(final["sat_part_17"]==1) != (final["sat_part_18"]==1)]
# Out:
#                    state  sat_part_17  sat_erw_17  sat_math_17  sat_total_17  \
# 5               Colorado         0.11         606          595          1201
# 8   District of Columbia         1.00         482          468           950
# 12                 Idaho         0.93         513          493          1005
#
#     act_part_17  act_eng_17  act_math_17  act_read_17  act_sci_17  ...  \
# 5          1.00        20.1         20.3         21.2        20.9  ...
# 8          0.32        24.4         23.5         24.9        23.5  ...
# 12         0.38        21.9         21.8         23.0        22.1  ...
#
#     sat_part_18  sat_erw_18  sat_math_18  sat_total_18  act_part_18  \
# 5          1.00         519          506          1025         0.30
# 8          0.92         497          480           977         0.32
# 12         1.00         508          493          1001         0.36
#
#     act_eng_18  act_math_18  act_read_18  act_sci_18  act_composite_18
# 5         23.9         23.2         24.4        23.5              23.9
# 8         23.7         22.7         24.4        23.0              23.6
# 12        21.9         21.6         23.2        22.1              22.3
#
# [3 rows x 21 columns]

# %%
#ACT
final[(final["act_part_17"]==1) != (final["act_part_18"]==1)]
# Out:
#         state  sat_part_17  sat_erw_17  sat_math_17  sat_total_17  \
# 5    Colorado         0.11         606          595          1201
# 22  Minnesota         0.03         644          651          1295
# 26   Nebraska         0.03         629          625          1253
# 34       Ohio         0.12         578          570          1149
#
#     act_part_17  act_eng_17  act_math_17  act_read_17  act_sci_17  ...  \
# 5          1.00        20.1         20.3         21.2        20.9  ...
# 22         1.00        20.4         21.5         21.8        21.6  ...
# 26         0.84        20.9         20.9         21.9        21.5  ...
# 34         0.75        21.2         21.6         22.5        22.0  ...
#
#     sat_part_18  sat_erw_18  sat_math_18  sat_total_18  act_part_18  \
# 5          1.00         519          506          1025         0.30
# 22         0.04         643          655          1298         0.99
# 26         0.03         629          623          1252         1.00
# 34         0.18         552          547          1099         1.00
#
#     act_eng_18  act_math_18  act_read_18  act_sci_18  act_composite_18
# 5         23.9         23.2         24.4        23.5              23.9
# 22        20.2         21.4         21.7        21.4              21.3
# 26        19.4         19.8         20.4        20.1              20.1
# 34        19.3         20.3         20.8        20.4              20.3
#
# [4 rows x 21 columns]

# %% [markdown]
# ##### Answer:
#
# 100% participation on SAT have a rate change from 2017 to 2018:
# - Colorado
# - District of Columbia
# - Idaho
#
# 100% participation on ACT have a rate change from 2017 to 2018:
# - Colorado
# - Minnesota
# - Nebraska
# - Ohio

# %% [markdown]
# ### Do any states show have >50% participation on both tests either year?

# %%
# 2017
final[(final["sat_part_17"] > 0.5) & (final["act_part_17"] > 0.5)]
# Out:
#       state  sat_part_17  sat_erw_17  sat_math_17  sat_total_17  act_part_17  \
# 9   Florida         0.83         520          497          1017         0.73
# 10  Georgia         0.61         535          515          1050         0.55
# 11   Hawaii         0.55         544          541          1085         0.90
#
#     act_eng_17  act_math_17  act_read_17  act_sci_17  ...  sat_part_18  \
# 9         19.0         19.4         21.0        19.4  ...         0.56
# 10        21.0         20.9         22.0        21.3  ...         0.70
# 11        17.8         19.2         19.2        19.3  ...         0.56
#
#     sat_erw_18  sat_math_18  sat_total_18  act_part_18  act_eng_18  \
# 9          550          549          1099         0.66        19.2
# 10         542          522          1064         0.53        20.9
# 11         480          530          1010         0.89        18.2
#
#     act_math_18  act_read_18  act_sci_18  act_composite_18
# 9          19.3         21.1        19.5              19.9
# 10         20.7         21.2        21.4              21.4
# 11         19.0         19.1        19.0              18.9
#
# [3 rows x 21 columns]

# %%
# 2018
final[(final["sat_part_18"] > 0.5) & (final["act_part_18"] > 0.5)]
# Out:
#              state  sat_part_17  sat_erw_17  sat_math_17  sat_total_17  \
# 9          Florida         0.83         520          497          1017
# 10         Georgia         0.61         535          515          1050
# 11          Hawaii         0.55         544          541          1085
# 32  North Carolina         0.49         546          535          1081
# 39  South Carolina         0.50         543          521          1064
#
#     act_part_17  act_eng_17  act_math_17  act_read_17  act_sci_17  ...  \
# 9          0.73        19.0         19.4         21.0        19.4  ...
# 10         0.55        21.0         20.9         22.0        21.3  ...
# 11         0.90        17.8         19.2         19.2        19.3  ...
# 32         1.00        17.8         19.3         19.6        19.3  ...
# 39         1.00        17.5         18.6         19.1        18.9  ...
#
#     sat_part_18  sat_erw_18  sat_math_18  sat_total_18  act_part_18  \
# 9          0.56         550          549          1099         0.66
# 10         0.70         542          522          1064         0.53
# 11         0.56         480          530          1010         0.89
# 32         0.52         554          543          1098         1.00
# 39         0.55         547          523          1070         1.00
#
#     act_eng_18  act_math_18  act_read_18  act_sci_18  act_composite_18
# 9         19.2         19.3         21.1        19.5              19.9
# 10        20.9         20.7         21.2        21.4              21.4
# 11        18.2         19.0         19.1        19.0              18.9
# 32        18.0         19.3         19.5        19.2              19.1
# 39        17.3         18.2         18.6        18.5              18.3
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### Answer:
#
# - In 2017, Florida, Georgia and Hawaii have a participation rate of more than 50% in both tests.
# - While in 2018, there are Florida, Georgia, Hawaii, North Carolina and South Carolina.

# %% [markdown]
# Based on what you've just observed, have you identified any states that you're especially interested in? Make a note of these and state why you think they're interesting.

# %% [markdown]
# ----> Proceed to the next notebook for [Data Visualisation](./03_Data_Visualisation.ipynb)
